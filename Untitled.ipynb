# %%
import pandas as pd

# %%
df = pd.read_csv("data/Transactions.csv")

# %%
df.head()
# Out:
#   customer_id transaction_id transaction_date credit_debit_code  \
# 0         ABC       ABC11111       2025-06-30                 C
# 1         ABC       ABC22222       2025-06-30                 D
# 2         ABC       ABC33333       2025-06-28                 C
# 3         ABC       ABC44444       2025-06-25                 D
# 4         ABC       ABC55555       2025-06-23                 D
#
#   transaction_type_code  transaction_value
# 0                 TXN01              100.0
# 1                 TXN01              100.0
# 2                 TXN01              100.0
# 3                 TXN01              100.0
# 4                 TXN01              100.0

# %%
df["customer_id"].unique()
# Out:
# array(['ABC', 'DEF', 'XYZ'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   customer_id            21 non-null     object
#  1   transaction_id         21 non-null     object
#  2   transaction_date       21 non-null     object
#  3   credit_debit_code      21 non-null     object
#  4   transaction_type_code  21 non-null     object
#  5   transaction_value      21 non-null     float64
# dtypes: float64(1), object(5)
# memory usage: 1.1+ KB

# %%
display(df.describe())
# Out:
#        transaction_value
# count               21.0
# mean               100.0
# std                  0.0
# min                100.0
# 25%                100.0
# 50%                100.0
# 75%                100.0
# max                100.0

# %%
print(df.isnull().sum())
# Out:
# customer_id              0
# transaction_id           0
# transaction_date         0
# credit_debit_code        0
# transaction_type_code    0
# transaction_value        0
# dtype: int64

# %%
df.shape
# Out:
# (21, 6)
